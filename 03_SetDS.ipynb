# %% [markdown]
# ## Set Data Structure
#
# 1. set only take unique elements.
# 2. unordered elements.
# 3. Mutable.
# 4. Can contain primitive and non primitive data type.

# %%
list=[12,'anik','bolik','sonik',12.5,'anik','12',12]
list2=[1,2,3,4,5]
list01=list+list2

# %%
setoflist=set(list01)
print(setoflist)
# Out:
# {1, 2, 'bolik', 3, '12', 4, 5, 12.5, 12, 'sonik', 'anik'}

# %%
setoflist.add(100)
print(setoflist)
# Out:
# {1, 2, 'bolik', 3, '12', 4, 5, 100, 12.5, 12, 'sonik', 'anik'}

# %%
setoflist.remove(1)
print(setoflist)
# Out:
# {2, 'bolik', 3, '12', 4, 5, 100, 12.5, 12, 'sonik', 'anik'}

# %% [markdown]
# ## add() and remove() method in set is inplace method. It will change the original set.

# %% [markdown]
# ## Set Operations
# 1. union
# 2. intersection
# 3. difference
# 4. symmetric difference
