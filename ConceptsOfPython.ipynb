# %% [markdown]
# <h2>Getting started here...</h2>
# <p>we need to understand what is that python understand and what is does not.</p>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
2
# Out:
# 2

# %%
-20
# Out:
# -20

# %%
100.3
# Out:
# 100.3

# %%
'some text'
# Out:
# 'some text'

# %%
'course fee: 100.3'
# Out:
# 'course fee: 100.3'

# %%
"This one is getting interesting"
# Out:
# 'This one is getting interesting'

# %%
True
# Out:
# True

# %%
FALSE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2648/640426746.py in <cell line: 0>()
# ----> 1 FALSE
#
# NameError: name 'FALSE' is not defined

# %%
False
# Out:
# False

# %% [markdown]
# Here we can see that FALSE is not defined in terms of Object in python!

# %%
$
# Out:
#   File "/tmp/ipykernel_2648/1334801704.py", line 1
#     $
#     ^
# SyntaxError: invalid syntax

# %%
string
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2648/41168278.py in <cell line: 0>()
# ----> 1 string
#
# NameError: name 'string' is not defined
